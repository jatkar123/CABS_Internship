# %%
from google.colab.patches import cv2_imshow
from google.colab.patches import cv2
import cv2
import glob
from matplotlib import image
from PIL import Image
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = cv2.imread('/content/drive/MyDrive/Marvel/carrier (14).jpg', 1)
#img = image.resize(img, (128,128))
size =(64,64)
background_color="white"
resized_img = np.array(resize_image(img, size, background_color))
cv2_imshow(img)


#path = glob.glob("/content/drive/MyDrive/Marvel/*.jpg")
#cv2_img = []
#for img in path:
#    n = cv2.imread(img)
#    cv2_img.append(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-9abd227d29d3> in <module>()
#       3 size =(64,64)
#       4 background_color="white"
# ----> 5 resized_img = np.array(resize_image(img, size, background_color))
#       6 cv2_imshow(img)
#       7
#
# NameError: name 'resize_image' is not defined

# %%
img = img.reshape((128,128))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-ca87499b1f00> in <module>()
# ----> 1 img = img.reshape((128,128))
#
# AttributeError: 'NoneType' object has no attribute 'reshape'

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=210x143 at 0x7F72FE553C50>

# %%
img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=210x143 at 0x7F72FE510890>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=210x143 at 0x7F72FE55B350>

# %%
def dodgeV2(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=210x143 at 0x7F72FE544990>
