# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from matplotlib import image 
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Reading image 
img = cv2.imread('/content/drive/MyDrive/ml_project/test/sketch/5.png', 1)
#from skimage import io 
#io.imshow(img)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8DC041CA50>

# %%
#Converting to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#io.imshow(img)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8DC0481050>

# %%
#Detecting edges of the input image
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur(gray, 5)
edges = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 9, 9)
#io.imshow(edges)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F8DC0481BD0>

# %%
#Cartoonifying the image
color = cv2.bilateralFilter(img, 9, 250, 250)
cartoon = cv2.bitwise_and(color, color, mask=edges)

# %%
#io.imshow(cartoon)
cv2_imshow(cartoon)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8DC0427810>
